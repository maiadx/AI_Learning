# %%
# follwed from Andrej Karpathy Video "Let's build GPT"

# %%
import torch
import torch.nn as nn
from torch.nn import functional as Func

# %%
# hyperparameters:
batch_size = 32  # how many independent sequences will we process in parallel?
block_size = 8   # what is the maximum context length for predictions?
max_iters = 3000 # training iters
eval_interval = 300
learning_rate = 1e-2
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200

torch.manual_seed(2073)
model = None
# Out:
# /home/flwrz/Dev/gpt-engine/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 803: system has unsupported display driver / cuda driver combination (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
with open('data/text.txt', encoding='utf-8') as fp:
    text = fp.read()

# %%
print(f"length of dataset in characters: {len(text)}\n")
print(f"\"{text[:60]}\" ")
# Out:
# length of dataset in characters: 1115393
#
# "First Citizen:
# Before we proceed any further, hear me speak."

# %%
vocab = sorted(list(set(text)))
vocab_size = len(vocab)
print(f"vocabulary: {''.join(vocab)}")
print(f"vocab size: {vocab_size}")
# Out:
# vocabulary:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65

# %% [markdown]
# Simple Tokenization

# %%
# strategy to tokensize text -> model is character-level,
#  so we need to translate characters into integers.

# encode - string to integers (list)
def encode(input_string):
    # Define the vocabulary    
    # Create a dictionary to map each character to an integer
    char_to_index = {char: idx for idx, char in enumerate(vocab)}
    
    # Convert input string to an array of integers based on the character mapping
    encoded_array = list(map(lambda char: char_to_index[char], input_string))    
    return encoded_array


def decode(encoded_data):
    
    # mapping for integers back into string:
    index_to_char = {idx: char for idx, char in enumerate(vocab)}

    # convert the array of integers back to a string based on the reverse mapping:
    decoded_string = ''.join(map(lambda idx: index_to_char.get(idx, ''), encoded_data))
    return decoded_string

# Example usage of encode and decode
input_str = "hii there"
encoded_output = encode(input_str)
print("Encoded:", encoded_output)

decoded_output = decode(encoded_output)
print("Decoded:", decoded_output)
# Out:
# Encoded: [46, 47, 47, 1, 58, 46, 43, 56, 43]
# Decoded: hii there

# %%
# Time to encode dataset
import torch
data = torch.tensor(encode(text), dtype=torch.long)

print(data.shape, data.dtype)
#print(data[:1000])
# Out:
# torch.Size([1115393]) torch.int64
# /tmp/ipykernel_59949/2609803937.py:3: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   data = torch.tensor(encode(text), dtype=torch.long)

# %% [markdown]
# Train / Test split

# %%
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

# %% [markdown]
# Training

# %%
# block : random sampled 'chunks' of dataset
# block_size = 8
train_data[:block_size+1]
# +1 because for a chunk of size 8, need to see what comes next?

x = train_data[:block_size]
y = train_data[1:block_size+1]

# y are the targets for each position in the input

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")

# we train on full range of context from 1 to block_size, because
# this makes transformer 'used to' seeing contexts in that range since it
# improves sampling during inference generality

# after block size we need ot truncate, since transformer can never recieve more than block_size inputs.
# Out:
# when input is tensor([18]) the target: 47
# when input is tensor([18, 47]) the target: 56
# when input is tensor([18, 47, 56]) the target: 57
# when input is tensor([18, 47, 56, 57]) the target: 58
# when input is tensor([18, 47, 56, 57, 58]) the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1]) the target: 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15]) the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47]) the target: 58

# %% [markdown]
# Batching

# %%
# batch dimension: we train on multiple different chunks of text,
# each with size block_size, to leverage gpu acceleration

#batch_size = 4
#block_size = 8

def get_batch(split):
    # gen a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))

    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()

        out[split] = losses.mean()
    
    model.train()
    return out

xb, yb = get_batch('train')

print(f"inputs: {xb.shape}, \n{xb}\n\ntargets: {yb.shape}\n{yb}")

print('------')

for b in range(batch_size):
    for t in range(block_size):
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target is: {target}")
# Out:
# inputs: torch.Size([32, 8]),
# tensor([[56, 39, 58, 43,  1, 51, 39, 52],
#         [57, 50, 47, 54,  1, 39, 58,  1],
#         [53, 52, 58, 39, 45, 59, 43,  6],
#         [ 1, 14, 43, 56, 49, 43, 50, 43],
#         [42,  1, 53, 52, 43,  7,  7, 61],
#         [57,  6,  1, 61, 46, 53,  0, 20],
#         [51, 43, 53,  8,  0,  0, 22, 33],
#         [61, 47, 44, 43,  6,  1, 57, 47],
#         [54, 53, 61, 43, 56,  1, 57, 58],
#         [ 1, 53, 59, 56,  1, 54, 39, 50],
#         [39, 51, 43,  1, 51, 53, 56, 43],
#         [ 1, 44, 50, 53, 61,  1, 61, 47],
#         [42,  1, 45, 43, 52, 58, 50, 43],
#         [43,  6,  1, 39, 52, 42,  1, 50],
#         [58, 46, 63, 57, 43, 50, 44, 12],
#         [ 1, 51, 63,  1, 40, 59, 56, 58],
#         [57, 61, 47, 51, 11,  1, 39, 50],
#         [ 1, 56, 43, 54, 56, 53, 53, 44],
#         [46,  1, 57, 59, 41, 49,  5, 42],
#         [50, 50,  7, 51, 63,  7, 42, 39],
#         [ 1, 41, 39, 52,  1, 39, 47, 42],
#         [42, 43, 57, 58, 56, 59, 41, 58],
#         [56,  6,  0, 32, 53,  1, 40, 43],
#         [51, 43,  1, 43, 52, 53, 59, 45],
#         [ 1, 63, 53, 59,  1, 39, 45, 56],
#         [ 1, 53, 44,  1, 58, 46, 47, 57],
#         [58,  1, 53, 44,  1, 63, 53, 59],
#         [59, 56,  1, 52, 53, 40, 50, 43],
#         [35, 53, 59, 50, 42,  1, 21,  1],
#         [56,  6,  1, 39, 57,  1, 61, 43],
#         [ 0, 13, 52, 42,  1, 56, 43, 39],
#         [57,  1, 52, 53, 61,  1, 52, 43]])
#
# targets: torch.Size([32, 8])
# tensor([[39, 58, 43,  1, 51, 39, 52, 11],
#         [50, 47, 54,  1, 39, 58,  1, 61],
#         [52, 58, 39, 45, 59, 43,  6,  0],
#         [14, 43, 56, 49, 43, 50, 43, 63],
#         [ 1, 53, 52, 43,  7,  7, 61, 46],
#         [ 6,  1, 61, 46, 53,  0, 20, 39],
#         [43, 53,  8,  0,  0, 22, 33, 24],
#         [47, 44, 43,  6,  1, 57, 47, 58],
#         [53, 61, 43, 56,  1, 57, 58, 47],
#         [53, 59, 56,  1, 54, 39, 50, 39],
#         [51, 43,  1, 51, 53, 56, 43,  1],
#         [44, 50, 53, 61,  1, 61, 47, 58],
#         [ 1, 45, 43, 52, 58, 50, 43, 51],
#         [ 6,  1, 39, 52, 42,  1, 50, 53],
#         [46, 63, 57, 43, 50, 44, 12,  0],
#         [51, 63,  1, 40, 59, 56, 58, 46],
#         [61, 47, 51, 11,  1, 39, 50, 39],
#         [56, 43, 54, 56, 53, 53, 44,  8],
#         [ 1, 57, 59, 41, 49,  5, 42,  1],
#         [50,  7, 51, 63,  7, 42, 39, 51],
#         [41, 39, 52,  1, 39, 47, 42,  1],
#         [43, 57, 58, 56, 59, 41, 58, 47],
#         [ 6,  0, 32, 53,  1, 40, 43, 39],
#         [43,  1, 43, 52, 53, 59, 45, 46],
#         [63, 53, 59,  1, 39, 45, 56, 43],
#         [53, 44,  1, 58, 46, 47, 57,  1],
#         [ 1, 53, 44,  1, 63, 53, 59, 56],
#         [56,  1, 52, 53, 40, 50, 43,  0],
#         [53, 59, 50, 42,  1, 21,  1, 46],
#         [ 6,  1, 39, 57,  1, 61, 43,  1],
#         [13, 52, 42,  1, 56, 43, 39, 56],
#         [ 1, 52, 53, 61,  1, 52, 43, 39]])
# ------
# when input is [56] the target is: 39
# when input is [56, 39] the target is: 58
# when input is [56, 39, 58] the target is: 43
# when input is [56, 39, 58, 43] the target is: 1
# when input is [56, 39, 58, 43, 1] the target is: 51
# when input is [56, 39, 58, 43, 1, 51] the target is: 39
# when input is [56, 39, 58, 43, 1, 51, 39] the target is: 52
# when input is [56, 39, 58, 43, 1, 51, 39, 52] the target is: 11
# when input is [57] the target is: 50
# when input is [57, 50] the target is: 47
# when input is [57, 50, 47] the target is: 54
# when input is [57, 50, 47, 54] the target is: 1
# when input is [57, 50, 47, 54, 1] the target is: 39
# when input is [57, 50, 47, 54, 1, 39] the target is: 58
# when input is [57, 50, 47, 54, 1, 39, 58] the target is: 1
# when input is [57, 50, 47, 54, 1, 39, 58, 1] the target is: 61
# when input is [53] the target is: 52
# when input is [53, 52] the target is: 58
# when input is [53, 52, 58] the target is: 39
# when input is [53, 52, 58, 39] the target is: 45
# when input is [53, 52, 58, 39, 45] the target is: 59
# when input is [53, 52, 58, 39, 45, 59] the target is: 43
# when input is [53, 52, 58, 39, 45, 59, 43] the target is: 6
# when input is [53, 52, 58, 39, 45, 59, 43, 6] the target is: 0
# when input is [1] the target is: 14
# when input is [1, 14] the target is: 43
# when input is [1, 14, 43] the target is: 56
# when input is [1, 14, 43, 56] the target is: 49
# when input is [1, 14, 43, 56, 49] the target is: 43
# when input is [1, 14, 43, 56, 49, 43] the target is: 50
# when input is [1, 14, 43, 56, 49, 43, 50] the target is: 43
# when input is [1, 14, 43, 56, 49, 43, 50, 43] the target is: 63
# when input is [42] the target is: 1
# when input is [42, 1] the target is: 53
# when input is [42, 1, 53] the target is: 52
# when input is [42, 1, 53, 52] the target is: 43
# when input is [42, 1, 53, 52, 43] the target is: 7
# when input is [42, 1, 53, 52, 43, 7] the target is: 7
# when input is [42, 1, 53, 52, 43, 7, 7] the target is: 61
# when input is [42, 1, 53, 52, 43, 7, 7, 61] the target is: 46
# when input is [57] the target is: 6
# when input is [57, 6] the target is: 1
# when input is [57, 6, 1] the target is: 61
# when input is [57, 6, 1, 61] the target is: 46
# when input is [57, 6, 1, 61, 46] the target is: 53
# when input is [57, 6, 1, 61, 46, 53] the target is: 0
# when input is [57, 6, 1, 61, 46, 53, 0] the target is: 20
# when input is [57, 6, 1, 61, 46, 53, 0, 20] the target is: 39
# when input is [51] the target is: 43
# when input is [51, 43] the target is: 53
# when input is [51, 43, 53] the target is: 8
# when input is [51, 43, 53, 8] the target is: 0
# when input is [51, 43, 53, 8, 0] the target is: 0
# when input is [51, 43, 53, 8, 0, 0] the target is: 22
# when input is [51, 43, 53, 8, 0, 0, 22] the target is: 33
# when input is [51, 43, 53, 8, 0, 0, 22, 33] the target is: 24
# when input is [61] the target is: 47
# when input is [61, 47] the target is: 44
# when input is [61, 47, 44] the target is: 43
# when input is [61, 47, 44, 43] the target is: 6
# when input is [61, 47, 44, 43, 6] the target is: 1
# when input is [61, 47, 44, 43, 6, 1] the target is: 57
# when input is [61, 47, 44, 43, 6, 1, 57] the target is: 47
# when input is [61, 47, 44, 43, 6, 1, 57, 47] the target is: 58
# when input is [54] the target is: 53
# when input is [54, 53] the target is: 61
# when input is [54, 53, 61] the target is: 43
# when input is [54, 53, 61, 43] the target is: 56
# when input is [54, 53, 61, 43, 56] the target is: 1
# when input is [54, 53, 61, 43, 56, 1] the target is: 57
# when input is [54, 53, 61, 43, 56, 1, 57] the target is: 58
# when input is [54, 53, 61, 43, 56, 1, 57, 58] the target is: 47
# when input is [1] the target is: 53
# when input is [1, 53] the target is: 59
# when input is [1, 53, 59] the target is: 56
# when input is [1, 53, 59, 56] the target is: 1
# when input is [1, 53, 59, 56, 1] the target is: 54
# when input is [1, 53, 59, 56, 1, 54] the target is: 39
# when input is [1, 53, 59, 56, 1, 54, 39] the target is: 50
# when input is [1, 53, 59, 56, 1, 54, 39, 50] the target is: 39
# when input is [39] the target is: 51
# when input is [39, 51] the target is: 43
# when input is [39, 51, 43] the target is: 1
# when input is [39, 51, 43, 1] the target is: 51
# when input is [39, 51, 43, 1, 51] the target is: 53
# when input is [39, 51, 43, 1, 51, 53] the target is: 56
# when input is [39, 51, 43, 1, 51, 53, 56] the target is: 43
# when input is [39, 51, 43, 1, 51, 53, 56, 43] the target is: 1
# when input is [1] the target is: 44
# when input is [1, 44] the target is: 50
# when input is [1, 44, 50] the target is: 53
# when input is [1, 44, 50, 53] the target is: 61
# when input is [1, 44, 50, 53, 61] the target is: 1
# when input is [1, 44, 50, 53, 61, 1] the target is: 61
# when input is [1, 44, 50, 53, 61, 1, 61] the target is: 47
# when input is [1, 44, 50, 53, 61, 1, 61, 47] the target is: 58
# when input is [42] the target is: 1
# when input is [42, 1] the target is: 45
# when input is [42, 1, 45] the target is: 43
# when input is [42, 1, 45, 43] the target is: 52
# when input is [42, 1, 45, 43, 52] the target is: 58
# when input is [42, 1, 45, 43, 52, 58] the target is: 50
# when input is [42, 1, 45, 43, 52, 58, 50] the target is: 43
# when input is [42, 1, 45, 43, 52, 58, 50, 43] the target is: 51
# when input is [43] the target is: 6
# when input is [43, 6] the target is: 1
# when input is [43, 6, 1] the target is: 39
# when input is [43, 6, 1, 39] the target is: 52
# when input is [43, 6, 1, 39, 52] the target is: 42
# when input is [43, 6, 1, 39, 52, 42] the target is: 1
# when input is [43, 6, 1, 39, 52, 42, 1] the target is: 50
# when input is [43, 6, 1, 39, 52, 42, 1, 50] the target is: 53
# when input is [58] the target is: 46
# when input is [58, 46] the target is: 63
# when input is [58, 46, 63] the target is: 57
# when input is [58, 46, 63, 57] the target is: 43
# when input is [58, 46, 63, 57, 43] the target is: 50
# when input is [58, 46, 63, 57, 43, 50] the target is: 44
# when input is [58, 46, 63, 57, 43, 50, 44] the target is: 12
# when input is [58, 46, 63, 57, 43, 50, 44, 12] the target is: 0
# when input is [1] the target is: 51
# when input is [1, 51] the target is: 63
# when input is [1, 51, 63] the target is: 1
# when input is [1, 51, 63, 1] the target is: 40
# when input is [1, 51, 63, 1, 40] the target is: 59
# when input is [1, 51, 63, 1, 40, 59] the target is: 56
# when input is [1, 51, 63, 1, 40, 59, 56] the target is: 58
# when input is [1, 51, 63, 1, 40, 59, 56, 58] the target is: 46
# when input is [57] the target is: 61
# when input is [57, 61] the target is: 47
# when input is [57, 61, 47] the target is: 51
# when input is [57, 61, 47, 51] the target is: 11
# when input is [57, 61, 47, 51, 11] the target is: 1
# when input is [57, 61, 47, 51, 11, 1] the target is: 39
# when input is [57, 61, 47, 51, 11, 1, 39] the target is: 50
# when input is [57, 61, 47, 51, 11, 1, 39, 50] the target is: 39
# when input is [1] the target is: 56
# when input is [1, 56] the target is: 43
# when input is [1, 56, 43] the target is: 54
# when input is [1, 56, 43, 54] the target is: 56
# when input is [1, 56, 43, 54, 56] the target is: 53
# when input is [1, 56, 43, 54, 56, 53] the target is: 53
# when input is [1, 56, 43, 54, 56, 53, 53] the target is: 44
# when input is [1, 56, 43, 54, 56, 53, 53, 44] the target is: 8
# when input is [46] the target is: 1
# when input is [46, 1] the target is: 57
# when input is [46, 1, 57] the target is: 59
# when input is [46, 1, 57, 59] the target is: 41
# when input is [46, 1, 57, 59, 41] the target is: 49
# when input is [46, 1, 57, 59, 41, 49] the target is: 5
# when input is [46, 1, 57, 59, 41, 49, 5] the target is: 42
# when input is [46, 1, 57, 59, 41, 49, 5, 42] the target is: 1
# when input is [50] the target is: 50
# when input is [50, 50] the target is: 7
# when input is [50, 50, 7] the target is: 51
# when input is [50, 50, 7, 51] the target is: 63
# when input is [50, 50, 7, 51, 63] the target is: 7
# when input is [50, 50, 7, 51, 63, 7] the target is: 42
# when input is [50, 50, 7, 51, 63, 7, 42] the target is: 39
# when input is [50, 50, 7, 51, 63, 7, 42, 39] the target is: 51
# when input is [1] the target is: 41
# when input is [1, 41] the target is: 39
# when input is [1, 41, 39] the target is: 52
# when input is [1, 41, 39, 52] the target is: 1
# when input is [1, 41, 39, 52, 1] the target is: 39
# when input is [1, 41, 39, 52, 1, 39] the target is: 47
# when input is [1, 41, 39, 52, 1, 39, 47] the target is: 42
# when input is [1, 41, 39, 52, 1, 39, 47, 42] the target is: 1
# when input is [42] the target is: 43
# when input is [42, 43] the target is: 57
# when input is [42, 43, 57] the target is: 58
# when input is [42, 43, 57, 58] the target is: 56
# when input is [42, 43, 57, 58, 56] the target is: 59
# when input is [42, 43, 57, 58, 56, 59] the target is: 41
# when input is [42, 43, 57, 58, 56, 59, 41] the target is: 58
# when input is [42, 43, 57, 58, 56, 59, 41, 58] the target is: 47
# when input is [56] the target is: 6
# when input is [56, 6] the target is: 0
# when input is [56, 6, 0] the target is: 32
# when input is [56, 6, 0, 32] the target is: 53
# when input is [56, 6, 0, 32, 53] the target is: 1
# when input is [56, 6, 0, 32, 53, 1] the target is: 40
# when input is [56, 6, 0, 32, 53, 1, 40] the target is: 43
# when input is [56, 6, 0, 32, 53, 1, 40, 43] the target is: 39
# when input is [51] the target is: 43
# when input is [51, 43] the target is: 1
# when input is [51, 43, 1] the target is: 43
# when input is [51, 43, 1, 43] the target is: 52
# when input is [51, 43, 1, 43, 52] the target is: 53
# when input is [51, 43, 1, 43, 52, 53] the target is: 59
# when input is [51, 43, 1, 43, 52, 53, 59] the target is: 45
# when input is [51, 43, 1, 43, 52, 53, 59, 45] the target is: 46
# when input is [1] the target is: 63
# when input is [1, 63] the target is: 53
# when input is [1, 63, 53] the target is: 59
# when input is [1, 63, 53, 59] the target is: 1
# when input is [1, 63, 53, 59, 1] the target is: 39
# when input is [1, 63, 53, 59, 1, 39] the target is: 45
# when input is [1, 63, 53, 59, 1, 39, 45] the target is: 56
# when input is [1, 63, 53, 59, 1, 39, 45, 56] the target is: 43
# when input is [1] the target is: 53
# when input is [1, 53] the target is: 44
# when input is [1, 53, 44] the target is: 1
# when input is [1, 53, 44, 1] the target is: 58
# when input is [1, 53, 44, 1, 58] the target is: 46
# when input is [1, 53, 44, 1, 58, 46] the target is: 47
# when input is [1, 53, 44, 1, 58, 46, 47] the target is: 57
# when input is [1, 53, 44, 1, 58, 46, 47, 57] the target is: 1
# when input is [58] the target is: 1
# when input is [58, 1] the target is: 53
# when input is [58, 1, 53] the target is: 44
# when input is [58, 1, 53, 44] the target is: 1
# when input is [58, 1, 53, 44, 1] the target is: 63
# when input is [58, 1, 53, 44, 1, 63] the target is: 53
# when input is [58, 1, 53, 44, 1, 63, 53] the target is: 59
# when input is [58, 1, 53, 44, 1, 63, 53, 59] the target is: 56
# when input is [59] the target is: 56
# when input is [59, 56] the target is: 1
# when input is [59, 56, 1] the target is: 52
# when input is [59, 56, 1, 52] the target is: 53
# when input is [59, 56, 1, 52, 53] the target is: 40
# when input is [59, 56, 1, 52, 53, 40] the target is: 50
# when input is [59, 56, 1, 52, 53, 40, 50] the target is: 43
# when input is [59, 56, 1, 52, 53, 40, 50, 43] the target is: 0
# when input is [35] the target is: 53
# when input is [35, 53] the target is: 59
# when input is [35, 53, 59] the target is: 50
# when input is [35, 53, 59, 50] the target is: 42
# when input is [35, 53, 59, 50, 42] the target is: 1
# when input is [35, 53, 59, 50, 42, 1] the target is: 21
# when input is [35, 53, 59, 50, 42, 1, 21] the target is: 1
# when input is [35, 53, 59, 50, 42, 1, 21, 1] the target is: 46
# when input is [56] the target is: 6
# when input is [56, 6] the target is: 1
# when input is [56, 6, 1] the target is: 39
# when input is [56, 6, 1, 39] the target is: 57
# when input is [56, 6, 1, 39, 57] the target is: 1
# when input is [56, 6, 1, 39, 57, 1] the target is: 61
# when input is [56, 6, 1, 39, 57, 1, 61] the target is: 43
# when input is [56, 6, 1, 39, 57, 1, 61, 43] the target is: 1
# when input is [0] the target is: 13
# when input is [0, 13] the target is: 52
# when input is [0, 13, 52] the target is: 42
# when input is [0, 13, 52, 42] the target is: 1
# when input is [0, 13, 52, 42, 1] the target is: 56
# when input is [0, 13, 52, 42, 1, 56] the target is: 43
# when input is [0, 13, 52, 42, 1, 56, 43] the target is: 39
# when input is [0, 13, 52, 42, 1, 56, 43, 39] the target is: 56
# when input is [57] the target is: 1
# when input is [57, 1] the target is: 52
# when input is [57, 1, 52] the target is: 53
# when input is [57, 1, 52, 53] the target is: 61
# when input is [57, 1, 52, 53, 61] the target is: 1
# when input is [57, 1, 52, 53, 61, 1] the target is: 52
# when input is [57, 1, 52, 53, 61, 1, 52] the target is: 43
# when input is [57, 1, 52, 53, 61, 1, 52, 43] the target is: 39

# %%
print(xb)
# Out:
# tensor([[56, 39, 58, 43,  1, 51, 39, 52],
#         [57, 50, 47, 54,  1, 39, 58,  1],
#         [53, 52, 58, 39, 45, 59, 43,  6],
#         [ 1, 14, 43, 56, 49, 43, 50, 43],
#         [42,  1, 53, 52, 43,  7,  7, 61],
#         [57,  6,  1, 61, 46, 53,  0, 20],
#         [51, 43, 53,  8,  0,  0, 22, 33],
#         [61, 47, 44, 43,  6,  1, 57, 47],
#         [54, 53, 61, 43, 56,  1, 57, 58],
#         [ 1, 53, 59, 56,  1, 54, 39, 50],
#         [39, 51, 43,  1, 51, 53, 56, 43],
#         [ 1, 44, 50, 53, 61,  1, 61, 47],
#         [42,  1, 45, 43, 52, 58, 50, 43],
#         [43,  6,  1, 39, 52, 42,  1, 50],
#         [58, 46, 63, 57, 43, 50, 44, 12],
#         [ 1, 51, 63,  1, 40, 59, 56, 58],
#         [57, 61, 47, 51, 11,  1, 39, 50],
#         [ 1, 56, 43, 54, 56, 53, 53, 44],
#         [46,  1, 57, 59, 41, 49,  5, 42],
#         [50, 50,  7, 51, 63,  7, 42, 39],
#         [ 1, 41, 39, 52,  1, 39, 47, 42],
#         [42, 43, 57, 58, 56, 59, 41, 58],
#         [56,  6,  0, 32, 53,  1, 40, 43],
#         [51, 43,  1, 43, 52, 53, 59, 45],
#         [ 1, 63, 53, 59,  1, 39, 45, 56],
#         [ 1, 53, 44,  1, 58, 46, 47, 57],
#         [58,  1, 53, 44,  1, 63, 53, 59],
#         [59, 56,  1, 52, 53, 40, 50, 43],
#         [35, 53, 59, 50, 42,  1, 21,  1],
#         [56,  6,  1, 39, 57,  1, 61, 43],
#         [ 0, 13, 52, 42,  1, 56, 43, 39],
#         [57,  1, 52, 53, 61,  1, 52, 43]])

# %% [markdown]
# Building our Neural Network

# %%
# bigram language model is the simplest model for nlp.
# bigram predicts next word solely based on the preceeding word. (n-gram where n = 2)
# P(W)=P(w1​)⋅P(w2​∣w1​)⋅P(w3​∣w2​)⋅…⋅P(wn​∣wn−1​)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits of the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):
            # idx and targets are both (B,T) tensor of integers
            logits = self.token_embedding_table(idx) # (B,T,C)
            # B, T, C: batch, time, channel

            if targets is None:
                loss = None
            else:
                # loss fn:
                # measures quality of logits w.r.t. the targets 
                # we have identity of next char, how well are we predicting next char based on logits?
                
                #pytorch expects different format for cross_entropy (B,C,T)
                # we need to reshape logits:
                B, T, C = logits.shape

                logits = logits.view(B*T, C)
                targets = targets.view(B*T)
                
                loss = Func.cross_entropy(logits, targets)



            return logits, loss


    def generate(self, idx, max_new_tokens):
        # idx is (B,T) array of indices in the current context

        for _ in range(max_new_tokens):
            # get predictions
            logits, loss = self(idx)

             # focus only on the last time step:
            logits = logits[:, -1, :] # becomes (B, C)

            # apply softmas to get probabilities:
            probs = Func.softmax(logits, dim=-1) # (B, C)

            # sample from distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)

            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)

        return idx
    



model = BigramLanguageModel(vocab_size)
logits, loss = model(xb, yb)
print(logits.shape)
print(loss)
# expecting loss to be (-1) * ln(1/65) = ~ 4.17

idx = torch.zeros((1,1), dtype=torch.long)
print(decode(model.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([256, 65])
# tensor(4.6496, grad_fn=<NllLossBackward0>)
#
# ,GI!dLhAQx.tQWA,sb.WXW,fG&,pO&&mg:x.nFv GMU!JzDuFipNeUEYF:dM M-&&uj.peNDlNTUUtUA!dMGbxUz!fQHfkN-;GZL

# %%
# load model to device: 
device_model = model.to(device)

# create a pytorch optimizer:
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)


# Training loop:
for steps in range(max_iters):

    if steps % eval_interval == 0:
        losses = estimate_loss()
        print(f"step: {iter}, train loss: {losses['train']:.4f}, val loss: {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# /home/flwrz/Dev/gpt-engine/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# step: <built-in function iter>, train loss: 4.5992, val loss: 4.6282
# step: <built-in function iter>, train loss: 4.2654, val loss: 4.2958
# step: <built-in function iter>, train loss: 3.9662, val loss: 3.9985
# step: <built-in function iter>, train loss: 3.7149, val loss: 3.7522
# step: <built-in function iter>, train loss: 3.5065, val loss: 3.5422
# step: <built-in function iter>, train loss: 3.3118, val loss: 3.3537
# step: <built-in function iter>, train loss: 3.1689, val loss: 3.2109
# step: <built-in function iter>, train loss: 3.0379, val loss: 3.0727
# step: <built-in function iter>, train loss: 2.9545, val loss: 2.9713
# step: <built-in function iter>, train loss: 2.8600, val loss: 2.8898

# %%
# generate from the model :
context = torch.zeros((1,1), dtype=torch.long, device=device)
print(decode(device_model.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# SLlarnerpV,nFrcinea.
# yhe ye GArhe ft hCEyouthqThee ll!I
# . Oms ste dp'zK:eno.3XAgyTN&DU-pof!
# BAxUAbepeRY:jAxtvuB$bzJowffoleing,3thak:d cYO
# AMAlwench usbofd st t ly than.OFpexctthe Y:
# LOUGLAUThe H'patheN:& fRKhe XzKubq?ZEWAst LANv
# :giruc$n-vCwhoou fron?
# Cab't.
# Ak3B,CZQtebinPER mBsellan Wil?-FXa.n s tvofes lNHef se nYerWvLouthct woucr w'therv&islltDY;K.A:D k;.$w
# aluWo?
# 'gaI:-fe t ss XDuzssor&3von oe d t bevat
# Lpprs.-ngv$
# y;yTh.wWhaghE Y tinthanLy ldJ$y tu's llel&VERSchatothalGI bQ?.ts rabCr?!d t d

# %%
# in the bigram language model, the tokens are not talking to eachother, so of course its going to be jibberish.
# though its more coherent after some training, its still very nonsensical.
# bigram is simple but also not very powerful.

# current impl only uses the last character to predict what comes next.


# how to get tokens to talk to eachother?

# %% [markdown]
# ### The mathematical trick in self-attention

# %%
# considre the following toy example:

B, T, C = 4, 8, 2 # batch, time, channels
x = torch.randn(B, T, C)
x.shape
# Out:
# torch.Size([4, 8, 2])
